# %% [markdown]
# # 샘플 테스트

# %%
st1 = [100, 110, 90, 105, 95, 102, 98]
st2 = [100, 130, 70, 120, 80, 160, 40]
x = list (  range(0, len(st1)))

# %%
#평균, 분산, 표준편차

# %%
import numpy as np

# %%
st1Mean = np.mean(st1)
st2Mean = np.mean(st2)
print(st1Mean, st2Mean)
# Out:
# 100.0 100.0

# %% [markdown]
# ### 분산 과 표준편차

# %%
st1Mean = np.mean(st1)
st1Len = len(st1)

answer = 0

for eachitem in st1:
    answer = answer + (st1Mean-eachitem) ** 2

stdValue = np.sqrt(answer / (st1Len))
stdValue
# Out:
# 6.07100838882165

# %%
stdValue
# Out:
# 6.07100838882165

# %%
st2Mean = np.mean(st2)
st2Len = len(st2)

answer2 = 0

for eachitem in st2:
    answer2 = answer2 + (st2Mean-eachitem) ** 2

std2Value = np.sqrt(answer2 / (st2Len-1))
std2Value
# Out:
# 40.414518843273804

# %%
import scipy

# %%
scipy.std
# Out:
# <function numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<no value>, *, where=<no value>)>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, st1, label = "st1")
plt.plot(x, st2, label = "st2")
plt.legend(loc=0)

# %% [markdown]
# # 1. 시각화 라이브러리

# %% [markdown]
# # 1. matpotlib 활용 차트 그리기

# %% [markdown]
# ### (1) 차트 그리기

# %%
# import pandas as pd

# selloutData = pd.read_csv("../dataset/kopo_product_volume.csv")

# selloutData["WEEK"] = selloutData.YEARWEEK.astype(str).str[4:6].astype(int)

# selloutData.head(2)

# groupKey = ["REGIONID","PRODUCTGROUP","WEEK"]

# groupData = selloutData.groupby(groupKey)["VOLUME"].agg(["mean"]).reset_index()
# groupData.rename(columns={"mean":"MEAN_VOLUME"}, inplace=True)

# %%
# groupData["MEAN_VOLUME"] = groupData.MEAN_VOLUME.astype(int)

# %%
# groupDataS01 = groupData.loc[ groupData.PRODUCTGROUP=="ST0001"]
# groupDataS02 = groupData.loc[ groupData.PRODUCTGROUP=="ST0002"]
# groupDataS01.head(5)

# %%
# groupDataS01.to_csv("../dataset/ST0001DATA.csv", index=False)
# groupDataS02.to_csv("../dataset/ST0002DATA.csv", index=False)

# %%
import pandas as pd

groupDataS01 = pd.read_csv("../dataset/ST0001DATA.csv")
groupDataS02 = pd.read_csv("../dataset/ST0002DATA.csv")
groupDataS02.head()
# Out:
#   REGIONID PRODUCTGROUP  WEEK  MEAN_VOLUME
# 0      A01       ST0002     1       158086
# 1      A01       ST0002     2       128312
# 2      A01       ST0002     3       127417
# 3      A01       ST0002     4       157127
# 4      A01       ST0002     5       197415

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# jupyter 상에서 바로 그래프 시현
# %matplotlib inline 

x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
# x=list(groupDataS01.WEEK)
# y=list(groupDataS01.MEAN_VOLUME)

# X축 값 범위 지정
plt.xticks( range(min(x),max(x),3) )
plt.plot(x,y)

# %% [markdown]
# ### (2) 차트 꾸미기

# %%
# x축 값 범위 지정
plt.xticks( range(min(x),max(x),3)  )
# X, Y축 라벨
plt.xlabel("week")
plt.ylabel("avg_volume")
# 차트 제목
plt.title("weekly trend")
# 선색상, 종류, 굵기 변경
plt.plot(x,y, "bo-", lw=2.5)

# %% [markdown]
# ### (3) 다중차트 라벨 설정

# %%
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

plt.xticks( range(min(x),max(x),3)  )
plt.plot(x,y,"go--", label="ST0001")
plt.plot(x,y2,"bo-", label="ST0002")

# 각 차트 별 표식 생성
plt.legend(loc=0)

# %% [markdown]
# ### 종합실습

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

# 차트 꾸미기
plt.plot(x,y,"go--", label="ST0001")
plt.plot(x,y2,"bo--", label="ST0002")
plt.grid(True) #그리드 표기
plt.xlabel('week') # x축 라벨
plt.ylabel('mean_volume') # y축 라벨
plt.title('volume by week') # 차트 제목
# Out:
# Text(0.5, 1.0, 'volume by week')

# %% [markdown]
# ### [실습]
# ../dataset/feature_regression_example.csv
#  데이터를 활용하여
# 2015년도 자료만 활용하여
# x축: week, y축: qty를 라인차트로 그리세요

# %%
import pandas as pd
featuresData =  pd.read_csv("../dataset/feature_regression_example.csv")

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
# 팝업 창 활용하여 차트 시연
x=featuresData2015[["WEEK"]]
y = featuresData2015[["QTY"]]
y2 = featuresData2016[["QTY"]]
# 차트 꾸미기, legend
plt.plot(x,y,"g", label="2015")
#plt.plot(x,y2,"bo--", label="2016")
plt.legend(loc=0)

# %%
### promotion 값도 같이 시각화!

# %% [markdown]
# # 2. matplotlib 활용 시각화 고급

# %% [markdown]
# ### (1) 서브플롯 그리기

# %%
import pandas as pd

groupDataS01 = pd.read_csv("../dataset/ST0001DATA.csv")
groupDataS02 = pd.read_csv("../dataset/ST0002DATA.csv")

# 필요 라이브러리 정의
import matplotlib.pyplot as plt
# 팝업 창 활용하여 차트 시연
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

# %%
fig = plt.figure(figsize=(14,4)) 
# 첫번째 차트
ax1 = fig.add_subplot(121)
ax1.plot(x,y, 'bo-',lw=1.5, label = 'ST0001') 
ax1.grid(True) 
ax1.legend(loc=0)
ax1.set_xlabel('ax1_index')
ax1.set_ylabel('ax1_value')
ax1.set_title('ax1_title')
# 두번째 차트
ax2 = fig.add_subplot(122) 
ax2.plot(x,y2, 'go-', lw=1.5, label='ST0002') 
ax2.grid(True) 
ax2.legend(loc=0)
ax2.set_xlabel('ax2_index')
ax2.set_ylabel('ax2_value')
ax2.set_title('ax2_title')
# Out:
# Text(0.5, 1.0, 'ax2_title')

# %% [markdown]
# ### (2) 이중축 그리기

# %%
# import matplotlib
# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : 14}

# %%
import pandas as pd

groupDataS01 = pd.read_csv("../dataset/ST0001DATA.csv")
groupDataS02 = pd.read_csv("../dataset/ST0002DATA.csv")

# 필요 라이브러리 정의
import matplotlib.pyplot as plt
# 팝업 창 활용하여 차트 시연
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME

# %%
test1 = groupDataS01.rename(columns={"MEAN_VOLUME":"VOLUME"})

# %%
totalSum = test1.VOLUME.sum()

# %%
test1["PERCENT"] = test1.WEEK/test1.WEEK.sum() * 100

# %%
x=test1.WEEK
y=test1.VOLUME
y2=test1.PERCENT

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

# # 팝업 창 활용하여 차트 시연
# x=groupDataS01.WEEK
# y=groupDataS01.MEAN_VOLUME
# y2=groupDataS02.MEAN_VOLUME

# 이중축
fig = plt.figure(figsize=(14,4))
ax1 = fig.add_subplot(1,1,1)
#figure, ax1 = plt.subplots(figsize=(10,5))
ax1.plot(x,y, 'bo-',lw=5, label = 'VOLUME')
ax1.grid(True)
ax1.legend(loc=0)
ax1.set_ylabel('ax1_value')
ax1.set_xlabel('ax1_index')
plt.title('subplot')
ax2 = ax1.twinx()
ax2.plot(x,y2, 'go-', lw=1.5, label='PERCENT')
ax2.legend(loc=4)
ax2.set_ylabel('ax2_value')
# Out:
# Text(0, 0.5, 'ax2_value')

# %% [markdown]
# ### [실습]
# ../dataset/feature_regression_example.csv
# 2015년도 자료만 활용하여
# x축: week 이중축으로 qty, pro_percent를
# 차트로 그리세요

# %%
import pandas as pd

featuresData =  pd.read_csv("../dataset/feature_regression_example.csv")

featuresData2015 = featuresData[ (featuresData.YEARWEEK >= 201501) &
                                (featuresData.YEARWEEK <= 201552)]

featuresData2015.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155
# 3  1810       Y      2         Y     0.208155
# 4  1773       N      4         Y     0.208155

# %% [markdown]
# ### (3) 막대차트 그리기

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt

x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME

fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.bar(x,y, width=0.8, label='ST0001')
ax1.legend(loc=0)
ax1.set_xlabel('WEEK')
ax1.set_ylabel('VOLUME')
# Out:
# Text(0, 0.5, 'VOLUME')

# %% [markdown]
# ### (4) 파이차트 그리기

# %%
# 필요 라이브러리 정의
import matplotlib.pyplot as plt

# 라벨 및 값 정의
groupLabel = ['A', 'B', 'C']
groupValue = [95, 54, 25]

# 파이차트 시각화
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.pie(x=groupValue,     
       labels=groupLabel,
       autopct="%1.2f%%",
       textprops={'fontsize': 12} )
ax1.legend(loc=0)

# %% [markdown]
# # 3. Seaborn

# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

csData = pd.read_csv("../dataset/customerdata.csv")
csData.head(2)
# Out:
#    CUSTID    AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.90000    3            6    1.679181  Big-Screen-lover
# 1  A14219  3642.44195    2            4    2.682023      Sleeping-dog

# %% [markdown]
# ### (1) 카운트 차트(count plot)

# %%
sns.countplot(data = csData, x="EMI", hue="CUSTTYPE")
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='count'>

# %% [markdown]
# ### (2) 히스토그램 (dist plot)

# %%
figure = plt.figure(figsize=(18,6))

ax1 = plt.subplot(1,2,1)
sns.distplot(csData.AVGPRICE, kde = False, ax=ax1 )
ax2 = plt.subplot(1,2,2)
sns.distplot(csData.AVGPRICE, hist = False, ax=ax2 )
# Out:
# C:\Users\kopo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kopo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AVGPRICE', ylabel='Density'>

# %% [markdown]
# ### (3) 바 차트 (bar plot)

# %%
sns.barplot(x="EMI", y="AVGPRICE", data = csData, 
         hue = "CUSTTYPE", ci = "sd")
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='AVGPRICE'>

# %% [markdown]
# ### (4) 박스 차트 (box plot)

# %%
sns.boxplot(data=csData, x="EMI", y="AVGPRICE")
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='AVGPRICE'>

# %% [markdown]
# ### (5) 선 차트 (line plot)

# %%
import pandas as pd
featuresData = pd.read_csv("../dataset/feature_regression_example.csv")
featuresData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155
# 3  1810       Y      2         Y     0.208155
# 4  1773       N      4         Y     0.208155

# %%
sns.lineplot(data=featuresData.loc[featuresData.YEAR==2015],
                                 x="WEEK", y="QTY")
# Out:
# <AxesSubplot:xlabel='WEEK', ylabel='QTY'>

# %% [markdown]
# #### 정답

# %%
# 필요 라이브러리 정의
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

groupDataS01 = pd.read_csv("https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/st0001data.csv")
groupDataS02 = pd.read_csv("https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/st0002data.csv")

# 팝업 창 활용하여 차트 시연
x=groupDataS01.WEEK
y=groupDataS01.MEAN_VOLUME
y2=groupDataS02.MEAN_VOLUME/500000

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)

ax2 = ax1.twinx()

c1 = sns.lineplot(ax = ax1, data =groupDataS01, x = 'WEEK', y = 'MEAN_VOLUME', color = 'red')
c2 = sns.lineplot(ax = ax2, data =groupDataS02, x = 'WEEK', y = 'MEAN_VOLUME', color = 'blue')

ax1.legend(['1st', '2nd'])

ax1.set_ylabel('week')
ax2.set_ylabel('promotion')
fig

# %% [markdown]
# ### 일반

# %%
# 이중축
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)

plt.plot(x,y, 'bo--',lw=1.5, label = '1st')
plt.grid(True)
plt.legend(loc=2)
plt.ylabel('qty')
plt.title('subplot')
ax2 = ax1.twinx()
plt.plot(x,y2, 'g', lw=1.5, label='2nd')
plt.legend(loc=4)
plt.xlabel('week')
plt.ylabel('promotion')
# Out:
# Text(0, 0.5, 'promotion')

# %% [markdown]
# ### (6) LM 차트 (lm plot)

# %%
sns.lmplot(data=featuresData, x="PRO_PERCENT",y="QTY")

# %%
featuresData.corr()
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT
# YEARWEEK     1.000000  0.956598  0.275593  0.112267 -0.071586     0.404889
# YEAR         0.956598  1.000000 -0.016493  0.028931  0.028593     0.321193
# WEEK         0.275593 -0.016493  1.000000  0.289766 -0.339943     0.329705
# QTY          0.112267  0.028931  0.289766  1.000000 -0.537230     0.700195
# HCLUS       -0.071586  0.028593 -0.339943 -0.537230  1.000000    -0.545619
# PRO_PERCENT  0.404889  0.321193  0.329705  0.700195 -0.545619     1.000000

# %% [markdown]
# ### (7) 조인트 차트 (joint plot)

# %%
sns.jointplot(data=csData, x= "AVGPRICE", y = "PRODUCTAGE")

# %% [markdown]
# ### [실습] https://github.com/mwaskom/seaborn-data 내 flights 및 tips 데이터를 활용하여 데이터를 시각화하세요

# %% [markdown]
# # 한글깨짐현상 가이드

# %%
import matplotlib.pyplot as plt
import matplotlib

font_name = matplotlib.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
matplotlib.rc('font', family=font_name)
print(font_name)
# Out:
# Malgun Gothic
